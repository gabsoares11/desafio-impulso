# %% [markdown]
# # Desafio de Modelagem e Análise de Dados - ImpulsoGov

# %% [markdown]
# ## Importando dados do <a href="http://datasource.coronacidades.org/help" style="color: gray">FarolCovid</a>

# %%
import pandas as pd

farol_data = pd.read_csv("http://datasource.coronacidades.org/br/cities/cases/full")
farol_data.head()
# Out:
#    active_cases  city_id              city_name city_notification_place_type  \
# 0          11.0  1100015  Alta Floresta D'Oeste                health_region
# 1          10.0  1100015  Alta Floresta D'Oeste                health_region
# 2           9.0  1100015  Alta Floresta D'Oeste                health_region
# 3           8.0  1100015  Alta Floresta D'Oeste                health_region
# 4           6.0  1100015  Alta Floresta D'Oeste                health_region
#
#    city_notification_rate  confirmed_cases  daily_cases  deaths  \
# 0                     NaN              1.0          1.0     0.0
# 1                     NaN              1.0          0.0     0.0
# 2                     NaN              1.0          0.0     0.0
# 3                     NaN              1.0          0.0     0.0
# 4                     NaN              1.0          0.0     0.0
#
#    epidemiological_week  estimated_population_2019  ...  last_updated  \
# 0                    18                    22945.0  ...    2020-05-02
# 1                    19                    22945.0  ...    2020-05-03
# 2                    19                    22945.0  ...    2020-05-04
# 3                    19                    22945.0  ...    2020-05-05
# 4                    19                    22945.0  ...    2020-05-06
#
#   new_deaths notification_rate  order_for_place  place_type  state_id  \
# 0        0.0          0.091429                1        city        RO
# 1        0.0          0.097143                2        city        RO
# 2        0.0          0.108571                3        city        RO
# 3        0.0          0.131429                4        city        RO
# 4        0.0          0.162857                5        city        RO
#
#    state_name  state_notification_rate state_num_id  data_last_refreshed
# 0    Rondônia                 0.715641           11  2020-08-30 00:11:17
# 1    Rondônia                 0.684133           11  2020-08-30 00:11:17
# 2    Rondônia                 0.645771           11  2020-08-30 00:11:17
# 3    Rondônia                 0.612698           11  2020-08-30 00:11:17
# 4    Rondônia                 0.605975           11  2020-08-30 00:11:17
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Importando dados do <a href="https://opendatasus.saude.gov.br/dataset/casos-nacionais" style="color: gray">OpenDataSUS</a>

# %%
obitos_pb = pd.read_csv("data/obitos_pb.csv")
obitos_pb.head()
# Out:
#          Método Município de Residência Inicio Sintomas       Sexo  \
# 0          Swab          Campina Grande      2020-07-04  Masculino
# 1  Teste Rápido          Pedras de Fogo      2020-06-18  Masculino
# 2  Teste Rápido             João Pessoa      2020-06-25   Feminino
# 3  Teste Rápido               Guarabira      2020-06-08   Feminino
# 4          Swab          Campina Grande      2020-08-07  Masculino
#
#            Doenças preexistentes Idade Data do Óbito
# 0  Hipertensão,Diabetes Mellitus    59    2020-07-19
# 1               Sem comorbidades    84    2020-08-07
# 2                   Doença Renal    95    2020-07-16
# 3                    Cardiopatia    80    2020-06-22
# 4               Sem comorbidades    76    2020-08-18

# %% [markdown]
# ## Selecionando apenas os casos/óbitos ocorridos em Campina Grande

# %%
farol_datacg = farol_data.loc[farol_data['city_name'] == 'Campina Grande']
farol_datacg.head()
# Out:
#         active_cases  city_id       city_name city_notification_place_type  \
# 153271           1.0  2504009  Campina Grande                          NaN
# 153272           2.0  2504009  Campina Grande                          NaN
# 153273           2.0  2504009  Campina Grande                          NaN
# 153274           2.0  2504009  Campina Grande                          NaN
# 153275           2.0  2504009  Campina Grande                          NaN
#
#         city_notification_rate  confirmed_cases  daily_cases  deaths  \
# 153271                     NaN              1.0          1.0     0.0
# 153272                     NaN              2.0          1.0     0.0
# 153273                     NaN              2.0          0.0     0.0
# 153274                     NaN              2.0          0.0     0.0
# 153275                     NaN              2.0          0.0     0.0
#
#         epidemiological_week  estimated_population_2019  ...  last_updated  \
# 153271                    13                   409731.0  ...    2020-03-27
# 153272                    13                   409731.0  ...    2020-03-28
# 153273                    14                   409731.0  ...    2020-03-29
# 153274                    14                   409731.0  ...    2020-03-30
# 153275                    14                   409731.0  ...    2020-03-31
#
#        new_deaths notification_rate  order_for_place  place_type  state_id  \
# 153271        0.0               NaN                1        city        PB
# 153272        0.0               NaN                2        city        PB
# 153273        0.0               NaN                3        city        PB
# 153274        0.0               NaN                4        city        PB
# 153275        0.0               NaN                5        city        PB
#
#         state_name  state_notification_rate state_num_id  data_last_refreshed
# 153271     Paraíba                      NaN           25  2020-08-30 00:11:17
# 153272     Paraíba                      NaN           25  2020-08-30 00:11:17
# 153273     Paraíba                      NaN           25  2020-08-30 00:11:17
# 153274     Paraíba                      NaN           25  2020-08-30 00:11:17
# 153275     Paraíba                      NaN           25  2020-08-30 00:11:17
#
# [5 rows x 30 columns]

# %%
# Convertendo os objetos da coluna para DateTime
obitos_pb['Data do Óbito'] = pd.to_datetime(obitos_pb['Data do Óbito'])

obitos_cg = obitos_pb.copy()[obitos_pb['Município de Residência'] == 'Campina Grande']
obitos_cg.head()
# Out:
#    Método Município de Residência Inicio Sintomas       Sexo  \
# 0    Swab          Campina Grande      2020-07-04  Masculino
# 4    Swab          Campina Grande      2020-08-07  Masculino
# 6    Swab          Campina Grande      2020-05-28  Masculino
# 9    Swab          Campina Grande      2020-06-29  Masculino
# 12   Swab          Campina Grande      2020-05-23  Masculino
#
#                                Doenças preexistentes Idade Data do Óbito
# 0                      Hipertensão,Diabetes Mellitus    59    2020-07-19
# 4                                   Sem comorbidades    76    2020-08-18
# 6   Diabetes Mellitus,Cardiopatia,Doença Neurológica    72    2020-07-01
# 9                                   Sem comorbidades    43    2020-07-16
# 12                     Hipertensão,Diabetes Mellitus    74    2020-06-01

# %% [markdown]
# ## Visualização dos dados

# %%
import numpy
import matplotlib.pyplot as plt

variables = obitos_cg['Sexo'].value_counts()
l = ['Masculino', 'Feminino']
c = ['#008B8B', '#00CED1']
explode = (0, 0.03)
fig1, ax1 = plt.subplots(figsize=(6,6))

plt.title('Visualização de óbitos por Covid-19 em Campina Grande por sexo', loc='center')
ax1.pie(variables, labels=l, colors=c, autopct='%0.2f%%', explode=explode);

# %%
mortes_mes = obitos_cg.sort_values('Data do Óbito')
mortes_mes = mortes_mes['Data do Óbito'].groupby([mortes_mes['Data do Óbito'].dt.month, mortes_mes['Sexo']]).agg('count')
mortes_mes
# Out:
# Data do Óbito  Sexo
# 4              Feminino      1
#                Masculino     1
# 5              Feminino     33
#                Masculino    38
# 6              Feminino     53
#                Masculino    59
# 7              Feminino     34
#                Masculino    45
# 8              Feminino     16
#                Masculino    17
# Name: Data do Óbito, dtype: int64

# %%
mortes_mes.groupby('Sexo').plot(figsize=(10,6));
plt.title('Visualização de mortes por mês classificado por sexo')
# Out:
# Text(0.5, 1.0, 'Visualização de mortes por mês classificado por sexo')
